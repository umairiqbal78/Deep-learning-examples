# %% [markdown]
# <a href="https://colab.research.google.com/github/umairiqbal78/Deep-learning-examples/blob/master/prediction_on_umair_vs_salman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')



from tensorflow.keras.models import load_model
model = load_model("drive/My Drive/model_umair_vs_salman1.h5")
# Out:
# Mounted at /content/drive

# %%
import math
from random import randint
predList = []

images = [7,45]
for i in images:
  img_path = f"/content/drive/My Drive/friends/orignal_images/{i}-.JPG"

  from tensorflow.keras.preprocessing import image
  import numpy as np

  img = image.load_img(img_path, target_size = (150,150))

  img_tensor = image.img_to_array(img)

  img_tensor = np.expand_dims(img_tensor, axis = 0)

  img_tensor /= 255.

  predList.append(model.predict(img_tensor))

  import matplotlib.pyplot  as plt
  plt.imshow(img_tensor[0])
  plt.show()

# %%
for pred in predList:
  if pred >= .50:
    print("UMAIR")
  else:
    print("SALMAN")
predList
# Out:
# UMAIR
# SALMAN
# [array([[0.9523114]], dtype=float32), array([[0.03069532]], dtype=float32)]

# %%
# Out:
# '20-09-29'

# %%
# Out:
# '/content/drive/My Drive/20-09-29'
